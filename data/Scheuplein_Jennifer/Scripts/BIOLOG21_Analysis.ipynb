# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Overview

time = np.array ([48,168,288])

# 21.05.2021

A1 = pd.read_excel (r'C:\Users\jenni\Desktop\Forschungspraktikum\Ustilago_maydis-GEM\data\Biolog Daten PM2A Platten.xlsx', sheet_name='21-05-2021')

myA1 = A1.iloc[1:9,1:13].values
myA2 = A1.iloc[11:19,1:13].values
myA3 = A1.iloc[21:29,1:13].values

myA1v = np.ndarray.flatten (myA1)
myA2v = np.ndarray.flatten (myA2)
myA3v = np.ndarray.flatten (myA3)

# 26.05.2021
B1 = pd.read_excel (r'C:\Users\jenni\Desktop\Forschungspraktikum\Ustilago_maydis-GEM\data\Biolog Daten PM2A Platten.xlsx', sheet_name='26-05-2021')

myB1 = B1.iloc[1:9,2:14].values
myB2 = B1.iloc[11:19,2:14].values
myB3 = B1.iloc[21:29,2:14].values

myB1v = np.ndarray.flatten (myB1)
myB2v = np.ndarray.flatten (myB2)
myB3v = np.ndarray.flatten (myB3)

# 31.05.2021
C1 = pd.read_excel (r'C:\Users\jenni\Desktop\Forschungspraktikum\Ustilago_maydis-GEM\data\Biolog Daten PM2A Platten.xlsx', sheet_name='31-05-2021')

myC1 = C1.iloc[1:9,2:14].values
myC2 = C1.iloc[11:19,2:14].values # empty in this case
myC3 = C1.iloc[21:29,2:14].values

myC1v = np.ndarray.flatten (myC1)
myC2v = np.ndarray.flatten (myC2)
myC3v = np.ndarray.flatten (myC3)

print (myC1, myC2, myC3)
# Out:
# [[0.057 0.066 0.077 0.047 0.084 0.166 0.082 0.105 0.096 0.65  0.08  0.117]
#  [0.259 0.268 0.181 0.617 0.956 1.21  0.726 0.211 0.143 0.857 0.86  0.105]
#  [0.53  0.309 0.253 1.019 1.01  0.828 0.197 0.047 0.158 0.274 0.448 0.891]
#  [0.508 0.77  0.188 0.108 0.389 0.2   1.209 0.725 0.117 0.64  0.392 0.931]
#  [0.042 0.047 0.36  0.186 0.047 0.48  0.448 0.861 0.17  0.22  0.124 0.311]
#  [0.656 0.435 0.145 0.195 0.101 1.071 0.23  0.948 0.047 0.486 0.128 0.247]
#  [0.191 0.69  0.217 0.278 0.424 0.325 0.329 0.134 1.005 1.087 0.528 0.322]
#  [0.217 0.959 0.057 0.057 0.041 0.061 0.047 0.039 0.05  0.217 0.341 0.255]] [[nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan]] [[0.057 0.064 0.088 0.078 0.086 0.23  0.098 0.118 0.087 0.677 0.135 0.085]
#  [0.208 0.257 0.085 0.259 0.802 1.314 0.771 0.187 0.187 0.673 0.906 0.041]
#  [0.606 0.258 0.214 1.198 0.964 0.752 0.169 0.073 0.127 0.224 0.488 0.722]
#  [0.873 0.953 0.252 0.077 0.412 0.18  0.859 0.822 0.094 0.709 0.359 1.059]
#  [0.043 0.043 0.364 0.272 0.046 0.741 0.33  0.929 0.182 0.276 0.411 0.174]
#  [0.886 0.481 0.421 0.079 0.157 1.267 0.207 0.996 0.237 0.54  0.148 0.236]
#  [0.241 0.656 0.132 0.146 0.466 0.042 0.04  0.073 0.903 1.076 0.559 0.289]
#  [0.703 0.485 0.189 0.239 0.042 0.041 0.043 0.04  0.517 0.185 0.122 0.174]]

# %%
# 21.05. std
myA_mean = np.mean ([myA1v, myA2v, myA3v], axis = 0)
myA_std = np.std ([myA1v, myA2v, myA3v], axis = 0)
myAw_mean = np.reshape (myA_mean, (8,12))
myAw_std = np.reshape (myA_std, (8,12))

y = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y_ticks = ['A','B','C','D','E','F','G','H']
plt.yticks(y, y_ticks)
plt.imshow(myAw_std, extent= [1, 12, 8, 1])

# %%
# 21.05. mean

myA_mean = np.mean ([myA1v, myA2v, myA3v], axis = 0)
myA_std = np.std ([myA1v, myA2v, myA3v], axis = 0)
myAw_mean = np.reshape (myA_mean, (8,12))
myAw_std = np.reshape (myA_std, (8,12))

y = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y_ticks = ['A','B','C','D','E','F','G','H']
plt.yticks(y, y_ticks)
plt.imshow(myAw_mean, extent= [1, 12, 8, 1])

# %%
# 26.05. std

myB_mean = np.mean ([myB1v, myB2v, myB3v], axis = 0)
myB_std = np.std ([myB1v, myB2v, myB3v], axis = 0)
myBw_mean = np.reshape (myB_mean, (8,12))
myBw_std = np.reshape (myB_std, (8,12))

y = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y_ticks = ['A','B','C','D','E','F','G','H']
plt.yticks(y, y_ticks)
plt.imshow(myBw_std, extent= [1, 12, 8, 1])

# %%
# 26.05. mean

myB_mean = np.mean ([myB1v, myB2v, myB3v], axis = 0)
myB_std = np.std ([myB1v, myB2v, myB3v], axis = 0)
myBw_mean = np.reshape (myB_mean, (8,12))
myBw_std = np.reshape (myB_std, (8,12))

y = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y_ticks = ['A','B','C','D','E','F','G','H']
plt.yticks(y, y_ticks)
plt.imshow(myBw_mean, extent= [1, 12, 8, 1])

# %%
# Mean 21.05. vs. 26.05, as Matrix

myDiff1 = myBw_mean - myAw_mean
myDiff1flat = np.ndarray.flatten (myDiff1)

print (myDiff1flat)

myDiff1_axis = np.std ([myDiff1flat], axis = 0)
myDiff1_reshape = np.reshape (myDiff1flat, (8,12))

y = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y_ticks = ['A','B','C','D','E','F','G','H']
plt.yticks(y, y_ticks)
plt.imshow(myDiff1_reshape, extent= [1, 12, 8, 1])
# Out:
# [-1.40000000e-02 -2.03333333e-02 -5.40000000e-02 -6.60000000e-02
#  -9.33333333e-03 -1.76666667e-02 -3.66666667e-03 -3.70000000e-02
#  -2.86666667e-02  2.84000000e-01 -2.86666667e-02 -4.22666667e-01
#  -4.66666667e-03 -1.63333333e-02  4.00000000e-03 -1.66666667e-02
#   5.16333333e-01  5.78666667e-01  8.57000000e-01 -1.06666667e-02
#   8.10000000e-02  8.70000000e-01  6.73333333e-01 -7.00000000e-03
#   1.38666667e-01 -2.26666667e-02 -4.66666667e-02  2.50333333e-01
#   4.88666667e-01  4.97666667e-01 -3.20000000e-02  8.66666667e-03
#  -2.30000000e-02  3.33333333e-03  1.86666667e-02  1.68333333e-01
#   4.41333333e-01  2.10000000e-01 -6.80000000e-02 -2.66666667e-03
#   6.50000000e-02 -5.80000000e-02  3.43666667e-01  5.44000000e-01
#  -5.76666667e-02  3.12333333e-01  9.83333333e-02  6.50333333e-01
#  -3.33333333e-04 -2.00000000e-03  2.43333333e-02 -1.70000000e-02
#  -1.33333333e-03  2.66666667e-01  4.00000000e-02  5.09333333e-01
#  -3.53333333e-02  1.33333333e-02  1.35333333e-01  3.86666667e-02
#   5.13000000e-01  7.03333333e-02  1.21666667e-01  1.56666667e-02
#   2.46666667e-02  4.68333333e-01 -5.66666667e-02  7.55000000e-01
#   1.51000000e-01  2.83000000e-01 -7.56666667e-02  2.26666667e-02
#   1.73333333e-02  2.83666667e-01 -3.93333333e-02  4.79666667e-01
#   2.17333333e-01 -1.04333333e-01 -7.70000000e-02 -1.26666667e-01
#   5.40000000e-01  5.86666667e-01  2.43333333e-01  7.76666667e-02
#   3.01000000e-01  1.55666667e-01  1.56666667e-02 -7.53333333e-02
#  -5.73333333e-02 -4.66666667e-03 -7.10000000e-02 -1.56333333e-01
#   1.40000000e-01  4.63333333e-02 -4.66666667e-03  4.80000000e-02]

# %%
# 31.05. std

myC_mean = np.mean ([myC1v, myC3v], axis = 0) # without C2 (empty)
myC_std = np.std ([myC1v, myC3v], axis = 0) # without C2 (empty)
myCw_mean = np.reshape (myC_mean, (8,12))
myCw_std = np.reshape (myC_std, (8,12))

y = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y_ticks = ['A','B','C','D','E','F','G','H']
plt.yticks(y, y_ticks)
plt.imshow(myCw_std, extent= [1, 12, 8, 1])

# %%
# 31.05. mean

myC_mean = np.mean ([myC1v, myC3v], axis = 0) # without C2 (empty)
myC_std = np.std ([myC1v, myC3v], axis = 0) # without C2 (empty)
myCw_mean = np.reshape (myC_mean, (8,12))
myCw_std = np.reshape (myC_std, (8,12))

y = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y_ticks = ['A','B','C','D','E','F','G','H']
plt.yticks(y, y_ticks)
plt.imshow(myCw_mean, extent= [1, 12, 8, 1])

# %%
# Mean 26.05. v.s 31.05. , as Matrix

myDiff2 = myCw_mean - myBw_mean
myDiff2flat = np.ndarray.flatten (myDiff1)

print (myDiff2flat)

myDiff2_axis = np.std ([myDiff2flat], axis = 0)
myDiff2_reshape = np.reshape (myDiff2flat, (8,12))

y = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y_ticks = ['A','B','C','D','E','F','G','H']
plt.yticks(y, y_ticks)
plt.imshow(myDiff2_reshape, extent= [1, 12, 8, 1])
# Out:
# [-1.40000000e-02 -2.03333333e-02 -5.40000000e-02 -6.60000000e-02
#  -9.33333333e-03 -1.76666667e-02 -3.66666667e-03 -3.70000000e-02
#  -2.86666667e-02  2.84000000e-01 -2.86666667e-02 -4.22666667e-01
#  -4.66666667e-03 -1.63333333e-02  4.00000000e-03 -1.66666667e-02
#   5.16333333e-01  5.78666667e-01  8.57000000e-01 -1.06666667e-02
#   8.10000000e-02  8.70000000e-01  6.73333333e-01 -7.00000000e-03
#   1.38666667e-01 -2.26666667e-02 -4.66666667e-02  2.50333333e-01
#   4.88666667e-01  4.97666667e-01 -3.20000000e-02  8.66666667e-03
#  -2.30000000e-02  3.33333333e-03  1.86666667e-02  1.68333333e-01
#   4.41333333e-01  2.10000000e-01 -6.80000000e-02 -2.66666667e-03
#   6.50000000e-02 -5.80000000e-02  3.43666667e-01  5.44000000e-01
#  -5.76666667e-02  3.12333333e-01  9.83333333e-02  6.50333333e-01
#  -3.33333333e-04 -2.00000000e-03  2.43333333e-02 -1.70000000e-02
#  -1.33333333e-03  2.66666667e-01  4.00000000e-02  5.09333333e-01
#  -3.53333333e-02  1.33333333e-02  1.35333333e-01  3.86666667e-02
#   5.13000000e-01  7.03333333e-02  1.21666667e-01  1.56666667e-02
#   2.46666667e-02  4.68333333e-01 -5.66666667e-02  7.55000000e-01
#   1.51000000e-01  2.83000000e-01 -7.56666667e-02  2.26666667e-02
#   1.73333333e-02  2.83666667e-01 -3.93333333e-02  4.79666667e-01
#   2.17333333e-01 -1.04333333e-01 -7.70000000e-02 -1.26666667e-01
#   5.40000000e-01  5.86666667e-01  2.43333333e-01  7.76666667e-02
#   3.01000000e-01  1.55666667e-01  1.56666667e-02 -7.53333333e-02
#  -5.73333333e-02 -4.66666667e-03 -7.10000000e-02 -1.56333333e-01
#   1.40000000e-01  4.63333333e-02 -4.66666667e-03  4.80000000e-02]
