# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Overview

time = np.array ([48,168,288])

# 21.05.2021

A1 = pd.read_excel (r'C:\Users\jenni\Desktop\Forschungspraktikum\Ustilago_maydis-GEM\data\Biolog Daten PM2A Platten.xlsx', sheet_name='21-05-2021')

myA1 = A1.iloc[1:9,1:13].values
myA2 = A1.iloc[11:19,1:13].values
myA3 = A1.iloc[21:29,1:13].values

myA1v = np.ndarray.flatten (myA1)
myA2v = np.ndarray.flatten (myA2)
myA3v = np.ndarray.flatten (myA3)

# 26.05.2021
B1 = pd.read_excel (r'C:\Users\jenni\Desktop\Forschungspraktikum\Ustilago_maydis-GEM\data\Biolog Daten PM2A Platten.xlsx', sheet_name='26-05-2021')

myB1 = B1.iloc[1:9,2:14].values
myB2 = B1.iloc[11:19,2:14].values
myB3 = B1.iloc[21:29,2:14].values

myB1v = np.ndarray.flatten (myB1)
myB2v = np.ndarray.flatten (myB2)
myB3v = np.ndarray.flatten (myB3)

# 31.05.2021
C1 = pd.read_excel (r'C:\Users\jenni\Desktop\Forschungspraktikum\Ustilago_maydis-GEM\data\Biolog Daten PM2A Platten.xlsx', sheet_name='31-05-2021')

myC1 = C1.iloc[1:9,2:14].values
myC2 = C1.iloc[11:19,2:14].values # empty in this case
myC3 = C1.iloc[21:29,2:14].values

myC1v = np.ndarray.flatten (myC1)
myC2v = np.ndarray.flatten (myC2)
myC3v = np.ndarray.flatten (myC3)

print (myC1, myC3)
# Out:
# [[0.066 0.077 0.047 0.084 0.166 0.082 0.105 0.096 0.65  0.08  0.117]
#  [0.268 0.181 0.617 0.956 1.21  0.726 0.211 0.143 0.857 0.86  0.105]
#  [0.309 0.253 1.019 1.01  0.828 0.197 0.047 0.158 0.274 0.448 0.891]
#  [0.77  0.188 0.108 0.389 0.2   1.209 0.725 0.117 0.64  0.392 0.931]
#  [0.047 0.36  0.186 0.047 0.48  0.448 0.861 0.17  0.22  0.124 0.311]
#  [0.435 0.145 0.195 0.101 1.071 0.23  0.948 0.047 0.486 0.128 0.247]
#  [0.69  0.217 0.278 0.424 0.325 0.329 0.134 1.005 1.087 0.528 0.322]
#  [0.959 0.057 0.057 0.041 0.061 0.047 0.039 0.05  0.217 0.341 0.255]] [[0.064 0.088 0.078 0.086 0.23  0.098 0.118 0.087 0.677 0.135 0.085]
#  [0.257 0.085 0.259 0.802 1.314 0.771 0.187 0.187 0.673 0.906 0.041]
#  [0.258 0.214 1.198 0.964 0.752 0.169 0.073 0.127 0.224 0.488 0.722]
#  [0.953 0.252 0.077 0.412 0.18  0.859 0.822 0.094 0.709 0.359 1.059]
#  [0.043 0.364 0.272 0.046 0.741 0.33  0.929 0.182 0.276 0.411 0.174]
#  [0.481 0.421 0.079 0.157 1.267 0.207 0.996 0.237 0.54  0.148 0.236]
#  [0.656 0.132 0.146 0.466 0.042 0.04  0.073 0.903 1.076 0.559 0.289]
#  [0.485 0.189 0.239 0.042 0.041 0.043 0.04  0.517 0.185 0.122 0.174]]

# %%
myA_mean = np.mean ([myA1v, myA2v, myA3v], axis = 0)
myA_std = np.std ([myA1v, myA2v, myA3v], axis = 0)
myAw_mean = np.reshape (myA_mean, (8,12))
myAw_std = np.reshape (myA_std, (8,12))

y = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y_ticks = ['A','B','C','D','E','F','G','H']
plt.yticks(y, y_ticks)
plt.imshow(myAw_std, extent= [1, 12, 8, 1])
plt.imshow(myAw_mean, extent= [1, 12, 8, 1])





# label ändern, Unterschiede der Mittelwerte 1 zu 2, 2 zu 3, wie verhalten se sich zu einander, in Matrix darstellen

# %%
myB_mean = np.mean ([myB1v, myB2v, myB3v], axis = 0)
myB_std = np.std ([myB1v, myB2v, myB3v], axis = 0)
myBw_mean = np.reshape (myB_mean, (8,12))
myBw_std = np.reshape (myB_std, (8,12))

y = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y_ticks = ['A','B','C','D','E','F','G','H']
plt.yticks(y, y_ticks)
plt.imshow(myBw_std, extent= [1, 12, 8, 1])
plt.imshow(myBw_mean, extent= [1, 12, 8, 1])

# %%
myC_mean = np.mean ([myC1v, myC2v, myC3v], axis = 0)
myC_std = np.std ([myC1v, myC2v, myC3v], axis = 0)
myCw_mean = np.reshape (myC_mean, (8,12))
myCw_std = np.reshape (myC_std, (8,12))

y = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y_ticks = ['A','B','C','D','E','F','G','H']
plt.yticks(y, y_ticks)
plt.imshow(myCw_std, extent= [1, 12, 8, 1])
plt.imshow(myCw_mean, extent= [1, 12, 8, 1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-731b008e559a> in <module>
#       1 myC_mean = np.mean ([myC1v, myC2v, myC3v], axis = 0)
#       2 myC_std = np.std ([myC1v, myC2v, myC3v], axis = 0)
# ----> 3 myCw_mean = np.reshape (myC_mean, (8,12))
#       4 myCw_std = np.reshape (myC_std, (8,12))
#       5
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in reshape(a, newshape, order)
#     297            [5, 6]])
#     298     """
# --> 299     return _wrapfunc(a, 'reshape', newshape, order=order)
#     300
#     301
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# ValueError: cannot reshape array of size 88 into shape (8,12)
